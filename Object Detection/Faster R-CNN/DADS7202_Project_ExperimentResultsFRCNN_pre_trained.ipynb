# %% [markdown]
# <a href="https://colab.research.google.com/github/pimpisaNga555/DADS7202_Project/blob/main/Object%20Detection/Faster%20R-CNN/DADS7202_Project_ExperimentResultsFRCNN_pre_trained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TensorFlow Object Detection API Installation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 57.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 85.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 KB 43.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# > **Cloning TFOD 2.0 Github**

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 80169, done.
# remote: Counting objects: 100% (354/354), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 80169 (delta 194), reused 314 (delta 174), pack-reused 79815
# Receiving objects: 100% (80169/80169), 594.53 MiB | 8.99 MiB/s, done.
# Resolving deltas: 100% (57048/57048), done.
# Checking out files: 100% (3300/3300), done.

# %% [markdown]
# > **Protobuf Installation/Compilation**

# %%
cd /content/drive/MyDrive/models/research
# Out:
# /content/drive/MyDrive/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %% [markdown]
# > **COCO API installation**

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 9.90 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd /content/drive/MyDrive/models/research/cocoapi/PythonAPI
# Out:
# /content/drive/MyDrive/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.8/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/drive/MyDrive/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/pycocotools
# ...

# %%
cp -r pycocotools /content/drive/MyDrive/models/research

# %% [markdown]
# > **Install the Object Detection API**

# %%
cd /content/drive/MyDrive/models/research
# Out:
# /content/drive/MyDrive/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/MyDrive/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 85.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 72.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 63.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 KB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 104.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# > **Test your Installation**

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-01-06 11:13:55.129162: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-06 11:13:55.129429: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-06 11:13:55.129464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Running tests under Python 3.8.16: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# ...

# %% [markdown]
# #Original

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# train 100 steps
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/Pretrained --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/Pretrained/pipeline.config
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0104 09:13:17.351153 140164748072832 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0104 09:13:17.357396 140164748072832 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0104 09:13:17.357582 140164748072832 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# ...

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/Pretrained --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/Pretrained/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/Pretrained
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0104 09:17:29.341589 140648543016832 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0104 09:17:29.341818 140648543016832 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0104 09:17:29.341916 140648543016832 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0104 09:17:29.341999 140648543016832 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %% [markdown]
# #Patch 2images Quadrangle shape and size 40% of boundiong box

# %% [markdown]
# ##Center

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Center -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_center/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_center/test.record

# %%
# !python model_main_tf2.py --model_dir=model_dir=/content/drive/MyDrive/DADS7202_Project2/Pretrained --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_center/pipeline2.config --checkpoint_dir=model_dir=/content/drive/MyDrive/DADS7202_Project2/Pretrained
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0104 07:56:10.424295 140444433389440 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0104 07:56:10.424534 140444433389440 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0104 07:56:10.424621 140444433389440 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0104 07:56:10.424704 140444433389440 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %% [markdown]
# ##Up 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Up_/5_up -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 17:39:36.205320: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:39:36.205431: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:39:36.205450: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Up_/10_up -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 17:53:19.702945: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:53:19.703059: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:53:19.703079: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Up_/15_up -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_up15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 17:59:43.370785: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:59:43.370910: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 17:59:43.370932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up to the right 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/UpRight_/5_upright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:07:30.543282: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:07:30.543436: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:07:30.543459: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up to the right 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/UpRight_/10_upright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:12:59.699629: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:12:59.699753: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:12:59.699774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up to the right 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/UpRight_/15_upright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upright15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:18:38.657051: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:18:38.657186: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:18:38.657209: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Right 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Right/5_right -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:49:43.043651: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:49:43.043781: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:49:43.043803: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Right 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Right/10_right -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:55:49.067626: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:55:49.067753: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:55:49.067774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Right 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Right/15_right -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_right15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:01:23.216057: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:01:23.216185: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:01:23.216206: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the right 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Downright/5_downright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:29:46.979054: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:29:46.979191: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:29:46.979214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the right 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Downright/10_downright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:35:34.693368: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:35:34.693504: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:35:34.693527: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the right 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Downright/15_downright -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downright15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:41:49.457766: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:41:49.457885: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:41:49.457904: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Down/5_down -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:06:54.929777: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:06:54.929896: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:06:54.929916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Down/10_down -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:13:21.355155: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:13:21.355291: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:13:21.355312: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Down/15_down -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_down15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:19:26.504093: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:19:26.504227: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:19:26.504248: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the left 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/DownLeft/5_downleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:29:27.551433: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:29:27.551550: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:29:27.551569: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the left 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/DownLeft/10_downleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:35:45.356261: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:35:45.356384: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:35:45.356405: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Down to the left 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/DownLeft/15_downleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_downleft15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:43:07.117215: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:43:07.117353: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:43:07.117375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Left 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Left/5_left -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:25:15.303601: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:25:15.303735: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:25:15.303756: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Left 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Left/10_left -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:30:18.083176: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:30:18.083311: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:30:18.083344: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Left 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Left/15_left -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_left15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:35:12.526174: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:35:12.526322: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:35:12.526345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up to the left 5%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Upleft_/5_upleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft5/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft5/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft5/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-02 18:43:21.089138: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:43:21.089275: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-02 18:43:21.089298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##Up to the left 10%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Upleft_/10_upleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft10/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft10/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft10/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:16:58.355754: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:16:58.355887: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:16:58.355911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# ##My_model Up to the left 15%

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Upleft_/15_upleft -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft15/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft15/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Rectangle_upleft15/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 09:23:00.296295: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:23:00.296420: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 09:23:00.296443: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# #Patch 2images Circle shape, fixed at the center of bounding box and size 40% of boundiong box

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/Circle_patch -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Circle_center/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Circle_center/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/Circle_center/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:48:01.950768: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:48:01.950895: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:48:01.950916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...

# %% [markdown]
# #Patch 2images S shape, fixed at the center of bounding box and size 40% of boundiong box

# %%
cd /content/drive/MyDrive/DADS7202_Project2
# Out:
# /content/drive/MyDrive/DADS7202_Project2

# %%
# Create test data
# !python generate_tfrecord.py -x /content/drive/MyDrive/DADS7202_Project2/AddPatch_All/S_patch -l /content/drive/MyDrive/DADS7202_Project2/annotations640/label_map.pbtxt -o /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/S_center/test.record
# Out:
# Successfully created the TFRecord file: /content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/S_center/test.record

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2 --pipeline_config_path=/content/drive/MyDrive/DADS7202_Project2/AddPatch_annotations/S_center/pipeline.config --checkpoint_dir=/content/drive/MyDrive/DADS7202_Project2/models640/my_frcnn2
# Out:
# 2023-01-03 10:54:24.960599: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:54:24.960729: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-03 10:54:24.960752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# ...
